# %%
import re
import pandas as pd
import bs4
import requests
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

from spacy.matcher import Matcher 
from spacy.tokens import Span 

import networkx as nx

import matplotlib.pyplot as plt
from tqdm import tqdm

pd.set_option('display.max_colwidth', 200)
# %matplotlib inline

# %%
# import wikipedia sentences
candidate_sentences = pd.read_csv("wiki_sentences_v2.csv")
candidate_sentences.shape
# Out:
# (4318, 1)

# %%
candidate_sentences['sentence'].sample(5)
# Out:
# 3049                                   i wanted to dive to the shipwreck.
# 448                increasingly, film festivals show some films outdoors.
# 2292        the deacon's protruding jaw was inspired by the goblin shark.
# 3675                     he also called the film a depressing experience.
# 1807    it was only involved in approximately 20 french film productions.
# Name: sentence, dtype: object

# %%
doc = nlp("the drawdown process is governed by astm standard d823")

for tok in doc:
  print(tok.text, "...", tok.dep_)
# Out:
# the ... det
# drawdown ... compound
# process ... nsubjpass
# is ... auxpass
# governed ... ROOT
# by ... agent
# astm ... compound
# standard ... pobj
# d823 ... punct

# %%
def get_entities(sent):
  ## chunk 1
  ent1 = ""
  ent2 = ""

  prv_tok_dep = ""    # dependency tag of previous token in the sentence
  prv_tok_text = ""   # previous token in the sentence

  prefix = ""
  modifier = ""

  #############################################################
  
  for tok in nlp(sent):
    ## chunk 2
    # if token is a punctuation mark then move on to the next token
    if tok.dep_ != "punct":
      # check: token is a compound word or not
      if tok.dep_ == "compound":
        prefix = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          prefix = prv_tok_text + " "+ tok.text
      
      # check: token is a modifier or not
      if tok.dep_.endswith("mod") == True:
        modifier = tok.text
        # if the previous word was also a 'compound' then add the current word to it
        if prv_tok_dep == "compound":
          modifier = prv_tok_text + " "+ tok.text
      
      ## chunk 3
      if tok.dep_.find("subj") == True:
        ent1 = modifier +" "+ prefix + " "+ tok.text
        prefix = ""
        modifier = ""
        prv_tok_dep = ""
        prv_tok_text = ""      

      ## chunk 4
      if tok.dep_.find("obj") == True:
        ent2 = modifier +" "+ prefix +" "+ tok.text
        
      ## chunk 5  
      # update variables
      prv_tok_dep = tok.dep_
      prv_tok_text = tok.text
  #############################################################

  return [ent1.strip(), ent2.strip()]

# %%
get_entities("the film had 200 patents")
# Out:
# ['film', '200  patents']

# %%
entity_pairs = []

for i in tqdm(candidate_sentences["sentence"]):
  entity_pairs.append(get_entities(i))
# Out:
# 100%|██████████| 4318/4318 [00:27<00:00, 155.37it/s]

# %%
entity_pairs[10:20]
# Out:
# [['we', 'tests'],
#  ['m', 'international sales rights'],
#  ['musician robbie robertson', 'soundtrack'],
#  ['it', 'original music tracks'],
#  ['it', 'reviewed  franchise'],
#  ['she', 'accidentally  mystique'],
#  ['military  forces', 'arrest'],
#  ['train', 'vuk'],
#  ['kota eberhardt', 'telepath selene gallio'],
#  ['singer', '-']]

# %%
def get_relation(sent):

  doc = nlp(sent)

  # Matcher class object 
  matcher = Matcher(nlp.vocab)

  #define the pattern 
  pattern = [[{'DEP':'ROOT'}, 
            {'DEP':'prep','OP':"?"},
            {'DEP':'agent','OP':"?"},  
            {'POS':'ADJ','OP':"?"}]] 

  # matcher.add("matching_1", None, pattern) 
  matcher.add("matching_1", patterns = pattern) 

  matches = matcher(doc)
  k = len(matches) - 1

  span = doc[matches[k][1]:matches[k][2]] 

  return(span.text)

# %%
get_relation("John completed the task")
# Out:
# 'completed'

# %%
relations = [get_relation(i) for i in tqdm(candidate_sentences['sentence'])]
# Out:
#   6%|▌         | 255/4318 [00:01<00:27, 149.03it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/toanlethanh/Documents/0_MSE/3_6_THESIS_SEM501/ToanLe/thesisSource/Untitled0.ipynb Cell 11' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/toanlethanh/Documents/0_MSE/3_6_THESIS_SEM501/ToanLe/thesisSource/Untitled0.ipynb#ch0000010?line=0'>1</a> relations = [get_relation(i) for i in tqdm(candidate_sentences['sentence'])]
#
# /Users/toanlethanh/Documents/0_MSE/3_6_THESIS_SEM501/ToanLe/thesisSource/Untitled0.ipynb Cell 11' in <listcomp>(.0)
# ----> <a href='vscode-notebook-cell:/Users/toanlethanh/Documents/0_MSE/3_6_THESIS_SEM501/ToanLe/thesisSource/Untitled0.ipynb#ch0000010?line=0'>1</a> relations = [get_relation(i) for i in tqdm(candidate_sentences['sentence'])]
#
# /Users/toanlethanh/Documents/0_MSE/3_6_THESIS_SEM501/ToanLe/thesisSource/Untitled0.ipynb Cell 9' in get_relation(sent)
#      <a href='vscode-notebook-cell:/Users/toanlethanh/Documents/0_MSE/3_6_THESIS_SEM501/ToanLe/thesisSource/Untitled0.ipynb#ch0000008?line=16'>17</a> matches = matcher(doc)
#      <a href='vscode-notebook-cell:/Users/toanlethanh/Documents/0_MSE/3_6_THESIS_SEM501/ToanLe/thesisSource/Untitled0.ipynb#ch0000008?line=17'>18</a> k = len(matches) - 1
# ---> <a href='vscode-notebook-cell:/Users/toanlethanh/Documents/0_MSE/3_6_THESIS_SEM501/ToanLe/thesisSource/Untitled0.ipynb#ch0000008?line=19'>20</a> span = doc[matches[k][1]:matches[k][2]]
#      <a href='vscode-notebook-cell:/Users/toanlethanh/Documents/0_MSE/3_6_THESIS_SEM501/ToanLe/thesisSource/Untitled0.ipynb#ch0000008?line=21'>22</a> return(span.text)
#
# IndexError: list index out of range
#   6%|▌         | 255/4318 [00:19<00:27, 149.03it/s]

# %%
pd.Series(relations).value_counts()[:50]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/toanlethanh/Documents/0_MSE/3_6_THESIS_SEM501/ToanLe/thesisSource/Untitled0.ipynb Cell 12' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/toanlethanh/Documents/0_MSE/3_6_THESIS_SEM501/ToanLe/thesisSource/Untitled0.ipynb#ch0000011?line=0'>1</a> pd.Series(relations).value_counts()[:50]
#
# NameError: name 'relations' is not defined

# %%
# extract subject
source = [i[0] for i in entity_pairs]

# extract object
target = [i[1] for i in entity_pairs]

kg_df = pd.DataFrame({'source':source, 'target':target, 'edge':relations})

# %%
# create a directed-graph from a dataframe
G=nx.from_pandas_edgelist(kg_df, "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

# %%
plt.figure(figsize=(12,12))

pos = nx.spring_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
G=nx.from_pandas_edgelist(kg_df[kg_df['edge']=="composed by"], "source", "target", 
                          edge_attr=True, create_using=nx.MultiDiGraph())

plt.figure(figsize=(12,12))
pos = nx.spring_layout(G, k = 0.5) # k regulates the distance between nodes
nx.draw(G, with_labels=True, node_color='skyblue', node_size=1500, edge_cmap=plt.cm.Blues, pos = pos)
plt.show()
